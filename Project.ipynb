# %% [markdown]
# <a href="https://colab.research.google.com/github/Adibank/DPDM/blob/master/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas

# %%
import pandas as pd

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# %%
base_path = '/content/drive/My Drive/DWDM_material'

# %%
os.listdir(base_path)
# Out:
# ['teach.csv',
#  '03 สังคม.xls',
#  '52835793_259306464964511_3851804852342489088_n.png',
#  'Copy of search_click.csv',
#  'Copy of w_restaurant.csv',
#  'Preprocessing02.html',
#  'reduced_marketbasket.csv',
#  'metadata.xlsx',
#  'search_click.csv',
#  'teach02.csv',
#  'test.csv',
#  'w_restaurant.csv',
#  'baboon.jpg',
#  'Project1.csv',
#  'Project1.xlsx',
#  'Project2.xlsx']

# %%
file_path_1 = os.path.join(base_path,'Project1.xlsx')

# %%
table_1 = pd.read_excel(file_path_1)

# %%
table_1
# Out:
#           จังหวัด  โรคสมองเสื่อม  ...  โรคทางจิตเวชอื่นๆ  โรคลมชัก
# 0          กระบี่            168  ...               2149      1231
# 1   กรุงเทพมหานคร           3002  ...              19838      5646
# 2       กาญจนบุรี            249  ...               5322      1881
# 3       กาฬสินธุ์            323  ...               5914      2143
# 4       กำแพงเพชร            146  ...               3897      1779
# ..            ...            ...  ...                ...       ...
# 73       อุดรธานี            614  ...               6121      3626
# 74      อุตรดิตถ์             86  ...               2120       693
# 75      อุทัยธานี            195  ...               4018       903
# 76    อุบลราชธานี            698  ...              11244      5920
# 77        ไม่ทราบ          10190  ...             154895     45030
#
# [78 rows x 19 columns]

# %%
file_path_2 = os.path.join(base_path,'Project2.xlsx')

# %%
table_2 = pd.read_excel(file_path_2)

# %%
table_2
# Out:
#        ปีที่เกิดเหตุ วันที่เกิดเหตุ   เวลา  ...  สภาพอากาศ   LATITUDE   LONGITUDE
# 0               2019     01/01/2019  00:00  ...     แจ่มใส  14.959105  100.873463
# 1               2019     01/01/2019  00:03  ...     แจ่มใส  15.210738  104.862689
# 2               2019     01/01/2019  00:05  ...     แจ่มใส  12.374259   99.907949
# 3               2019     01/01/2019  00:20  ...     แจ่มใส  18.601721   98.804204
# 4               2019     01/01/2019  00:25  ...     แจ่มใส  15.866389  100.590010
# ...              ...            ...    ...  ...        ...        ...         ...
# 19960           2019     31/12/2019  23:30  ...     แจ่มใส  15.171119   98.462388
# 19961           2019     31/12/2019  23:35  ...     แจ่มใส   8.092608   98.811692
# 19962           2019     31/12/2019  23:40  ...  หมอก/ควัน   9.939225   98.633500
# 19963           2019     31/12/2019  23:40  ...     แจ่มใส  18.829234   99.006029
# ...

# %%
table_1.shape
# Out:
# (78, 19)

# %%
table_2.shape
# Out:
# (19965, 20)

# %%
disease = table_1

# %%
disease
# Out:
#           จังหวัด  โรคสมองเสื่อม  ...  โรคทางจิตเวชอื่นๆ  โรคลมชัก
# 0          กระบี่            168  ...               2149      1231
# 1   กรุงเทพมหานคร           3002  ...              19838      5646
# 2       กาญจนบุรี            249  ...               5322      1881
# 3       กาฬสินธุ์            323  ...               5914      2143
# 4       กำแพงเพชร            146  ...               3897      1779
# ..            ...            ...  ...                ...       ...
# 73       อุดรธานี            614  ...               6121      3626
# 74      อุตรดิตถ์             86  ...               2120       693
# 75      อุทัยธานี            195  ...               4018       903
# 76    อุบลราชธานี            698  ...              11244      5920
# 77        ไม่ทราบ          10190  ...             154895     45030
#
# [78 rows x 19 columns]

# %%
accident = table_2

# %%
accident
# Out:
#        ปีที่เกิดเหตุ วันที่เกิดเหตุ   เวลา  ...  สภาพอากาศ   LATITUDE   LONGITUDE
# 0               2019     01/01/2019  00:00  ...     แจ่มใส  14.959105  100.873463
# 1               2019     01/01/2019  00:03  ...     แจ่มใส  15.210738  104.862689
# 2               2019     01/01/2019  00:05  ...     แจ่มใส  12.374259   99.907949
# 3               2019     01/01/2019  00:20  ...     แจ่มใส  18.601721   98.804204
# 4               2019     01/01/2019  00:25  ...     แจ่มใส  15.866389  100.590010
# ...              ...            ...    ...  ...        ...        ...         ...
# 19960           2019     31/12/2019  23:30  ...     แจ่มใส  15.171119   98.462388
# 19961           2019     31/12/2019  23:35  ...     แจ่มใส   8.092608   98.811692
# 19962           2019     31/12/2019  23:40  ...  หมอก/ควัน   9.939225   98.633500
# 19963           2019     31/12/2019  23:40  ...     แจ่มใส  18.829234   99.006029
# ...

# %%
num_accident = accident.groupby('จังหวัด').count().iloc[:,1:2]

# %%
num_accident
# Out:
#                วันที่เกิดเหตุ
# จังหวัด
# กระบี่                    205
# กรุงเทพมหานคร            1844
# กาญจนบุรี                 285
# กาฬสินธุ์                 130
# กำแพงเพชร                 188
# ...                       ...
# เพชรบุรี                  198
# เพชรบูรณ์                 395
# เลย                       196
# แพร่                      328
# แม่ฮ่องสอน                 90
#
# [77 rows x 1 columns]

# %%
num_accident.rename(columns={'วันที่เกิดเหตุ':'จำนวนครั้งที่เกิดเหตุ'}, inplace= True)
num_accident
# Out:
#                จำนวนครั้งที่เกิดเหตุ
# จังหวัด
# กระบี่                           205
# กรุงเทพมหานคร                   1844
# กาญจนบุรี                        285
# กาฬสินธุ์                        130
# กำแพงเพชร                        188
# ...                              ...
# เพชรบุรี                         198
# เพชรบูรณ์                        395
# เลย                              196
# แพร่                             328
# แม่ฮ่องสอน                        90
#
# [77 rows x 1 columns]

# %%
merged_table = disease.merge(num_accident,how='left',left_on='จังหวัด',right_on='จังหวัด')

# %%
merged_table
# Out:
#           จังหวัด  โรคสมองเสื่อม  ...  โรคลมชัก  จำนวนครั้งที่เกิดเหตุ
# 0          กระบี่            168  ...      1231                  205.0
# 1   กรุงเทพมหานคร           3002  ...      5646                 1844.0
# 2       กาญจนบุรี            249  ...      1881                  285.0
# 3       กาฬสินธุ์            323  ...      2143                  130.0
# 4       กำแพงเพชร            146  ...      1779                  188.0
# ..            ...            ...  ...       ...                    ...
# 73       อุดรธานี            614  ...      3626                  206.0
# 74      อุตรดิตถ์             86  ...       693                  289.0
# 75      อุทัยธานี            195  ...       903                  114.0
# 76    อุบลราชธานี            698  ...      5920                  186.0
# 77        ไม่ทราบ          10190  ...     45030                    NaN
#
# [78 rows x 20 columns]

# %% [markdown]
# # Missing Values

# %%
merged_table.isnull()
# Out:
#     จังหวัด  โรคสมองเสื่อม  ...  โรคลมชัก  จำนวนครั้งที่เกิดเหตุ
# 0     False          False  ...     False                  False
# 1     False          False  ...     False                  False
# 2     False          False  ...     False                  False
# 3     False          False  ...     False                  False
# 4     False          False  ...     False                  False
# ..      ...            ...  ...       ...                    ...
# 73    False          False  ...     False                  False
# 74    False          False  ...     False                  False
# 75    False          False  ...     False                  False
# 76    False          False  ...     False                  False
# 77    False          False  ...     False                   True
#
# [78 rows x 20 columns]

# %%
merged_table.isnull().any()
# Out:
# จังหวัด                                      False
# โรคสมองเสื่อม                                False
# ติดแอลกอฮอลล์                                False
# ติดยาบ้า (Amphetamine)                       False
# ติดสารเสพติดอื่นๆ                            False
# โรคจิตเภท                                    False
# โรคจิตอื่นๆ                                  False
# โรคอารมณ์สองขั้ว                             False
# โรคซึมเศร้า                                  False
# โรควิตกกังวล                                 False
# ความบกพร่องทางสติปัญญา                       False
# ความบกพร่องทางการเรียนรู้                    False
# โรคออทิสติก                                  False
# โรคสมาธิสั้น                                 False
# พยามยามฆ่าตัวตาย (การตั้งใจทำร้ายตนเอง)      False
# ผู้ป่วยติดเกมส์ในผู้ใหญ่ (15 ปีขึ้นไป)       False
# ผู้ป่วยติดเกมส์ในเด็ก (อายุต่ำกว่า 15 ปี)    False
# โรคทางจิตเวชอื่นๆ                            False
# ...

# %%
merged_table.isnull().any().any()
# Out:
# True

# %%
merged_table_nm = merged_table.dropna()

# %%
merged_table_nm
# Out:
#           จังหวัด  โรคสมองเสื่อม  ...  โรคลมชัก  จำนวนครั้งที่เกิดเหตุ
# 0          กระบี่            168  ...      1231                  205.0
# 1   กรุงเทพมหานคร           3002  ...      5646                 1844.0
# 2       กาญจนบุรี            249  ...      1881                  285.0
# 3       กาฬสินธุ์            323  ...      2143                  130.0
# 4       กำแพงเพชร            146  ...      1779                  188.0
# ..            ...            ...  ...       ...                    ...
# 72     อำนาจเจริญ             99  ...       957                   51.0
# 73       อุดรธานี            614  ...      3626                  206.0
# 74      อุตรดิตถ์             86  ...       693                  289.0
# 75      อุทัยธานี            195  ...       903                  114.0
# 76    อุบลราชธานี            698  ...      5920                  186.0
#
# [76 rows x 20 columns]

# %%
merged_table_nm.isnull().any().any()
# Out:
# False

# %%
num_accident_no_nm = merged_table_nm[['จังหวัด','จำนวนครั้งที่เกิดเหตุ']]

# %%
num_accident_no_nm
# Out:
#           จังหวัด  จำนวนครั้งที่เกิดเหตุ
# 0          กระบี่                  205.0
# 1   กรุงเทพมหานคร                 1844.0
# 2       กาญจนบุรี                  285.0
# 3       กาฬสินธุ์                  130.0
# 4       กำแพงเพชร                  188.0
# ..            ...                    ...
# 72     อำนาจเจริญ                   51.0
# 73       อุดรธานี                  206.0
# 74      อุตรดิตถ์                  289.0
# 75      อุทัยธานี                  114.0
# 76    อุบลราชธานี                  186.0
#
# [76 rows x 2 columns]

# %%
small = num_accident_no_nm[num_accident_no_nm['จำนวนครั้งที่เกิดเหตุ']<=100]
small
# Out:
#         จังหวัด  จำนวนครั้งที่เกิดเหตุ
# 10      ชัยภูมิ                   70.0
# 15         ตราด                   95.0
# 17      นครนายก                   96.0
# 27    บุรีรัมย์                   95.0
# 34        พังงา                   72.0
# 36       พิจิตร                   93.0
# 44   แม่ฮ่องสอน                   90.0
# 46         ยะลา                   72.0
# 48        ระนอง                   35.0
# 58         สตูล                   86.0
# 64    สิงห์บุรี                   96.0
# 69      หนองคาย                   93.0
# 70  หนองบัวลำภู                   76.0
# 72   อำนาจเจริญ                   51.0

# %%
small.shape
# Out:
# (14, 2)

# %%
m = num_accident_no_nm[num_accident_no_nm['จำนวนครั้งที่เกิดเหตุ']>100]
m
# Out:
#           จังหวัด  จำนวนครั้งที่เกิดเหตุ
# 0          กระบี่                  205.0
# 1   กรุงเทพมหานคร                 1844.0
# 2       กาญจนบุรี                  285.0
# 3       กาฬสินธุ์                  130.0
# 4       กำแพงเพชร                  188.0
# ..            ...                    ...
# 71        อ่างทอง                  180.0
# 73       อุดรธานี                  206.0
# 74      อุตรดิตถ์                  289.0
# 75      อุทัยธานี                  114.0
# 76    อุบลราชธานี                  186.0
#
# [62 rows x 2 columns]

# %%
middle = m[m['จำนวนครั้งที่เกิดเหตุ']<=200]
middle
# Out:
#         จังหวัด  จำนวนครั้งที่เกิดเหตุ
# 3     กาฬสินธุ์                  130.0
# 4     กำแพงเพชร                  188.0
# 9        ชัยนาท                  189.0
# 19       นครพนม                  110.0
# 23      นนทบุรี                  159.0
# 24     นราธิวาส                  116.0
# 26       บึงกาฬ                  115.0
# 31      ปัตตานี                  111.0
# 33        พะเยา                  168.0
# 38     เพชรบุรี                  198.0
# 41       ภูเก็ต                  134.0
# 42    มหาสารคาม                  145.0
# 43     มุกดาหาร                  164.0
# 45        ยโสธร                  119.0
# 47     ร้อยเอ็ด                  182.0
# 50      ราชบุรี                  124.0
# 54          เลย                  196.0
# 55     ศรีสะเกษ                  136.0
# 60  สมุทรสงคราม                  163.0
# 62      สระแก้ว                  197.0
# 65      สุโขทัย                  196.0
# 71      อ่างทอง                  180.0
# 75    อุทัยธานี                  114.0
# ...

# %%
middle.shape
# Out:
# (24, 2)

# %%
big = num_accident_no_nm[num_accident_no_nm['จำนวนครั้งที่เกิดเหตุ']>=200]
big
# Out:
#             จังหวัด  จำนวนครั้งที่เกิดเหตุ
# 0            กระบี่                  205.0
# 1     กรุงเทพมหานคร                 1844.0
# 2         กาญจนบุรี                  285.0
# 5           ขอนแก่น                  340.0
# 6          จันทบุรี                  343.0
# 7        ฉะเชิงเทรา                  276.0
# 8            ชลบุรี                  938.0
# 11            ชุมพร                  257.0
# 12         เชียงราย                  243.0
# 13        เชียงใหม่                  372.0
# 14             ตรัง                  203.0
# 16              ตาก                  461.0
# 18           นครปฐม                  317.0
# 20       นครราชสีมา                  877.0
# 21    นครศรีธรรมราช                  278.0
# 22        นครสวรรค์                  376.0
# 25             น่าน                  272.0
# 28         ปทุมธานี                  409.0
# 29  ประจวบคีรีขันธ์                  214.0
# 30       ปราจีนบุรี                  209.0
# 35           พัทลุง                  268.0
# ...

# %%
big.shape
# Out:
# (38, 2)

# %%
small['จำนวนครั้งที่เกิดเหตุ']
# Out:
# 10    70.0
# 15    95.0
# 17    96.0
# 27    95.0
# 34    72.0
# 36    93.0
# 44    90.0
# 46    72.0
# 48    35.0
# 58    86.0
# 64    96.0
# 69    93.0
# 70    76.0
# 72    51.0
# Name: จำนวนครั้งที่เกิดเหตุ, dtype: float64

# %%
middle['จำนวนครั้งที่เกิดเหตุ']
# Out:
# 3     130.0
# 4     188.0
# 9     189.0
# 19    110.0
# 23    159.0
# 24    116.0
# 26    115.0
# 31    111.0
# 33    168.0
# 38    198.0
# 41    134.0
# 42    145.0
# 43    164.0
# 45    119.0
# 47    182.0
# 50    124.0
# 54    196.0
# 55    136.0
# 60    163.0
# 62    197.0
# 65    196.0
# 71    180.0
# 75    114.0
# 76    186.0
# Name: จำนวนครั้งที่เกิดเหตุ, dtype: float64

# %%
big['จำนวนครั้งที่เกิดเหตุ']
# Out:
# 0      205.0
# 1     1844.0
# 2      285.0
# 5      340.0
# 6      343.0
# 7      276.0
# 8      938.0
# 11     257.0
# 12     243.0
# 13     372.0
# 14     203.0
# 16     461.0
# 18     317.0
# 20     877.0
# 21     278.0
# 22     376.0
# 25     272.0
# 28     409.0
# 29     214.0
# 30     209.0
# 35     268.0
# 37     226.0
# 39     395.0
# 40     328.0
# 49     237.0
# 51     283.0
# 52     266.0
# 53     235.0
# 56     234.0
# 57     344.0
# 59     649.0
# 61     279.0
# 63     310.0
# 66     727.0
# 67     415.0
# 68     239.0
# 73     206.0
# 74     289.0
# Name: จำนวนครั้งที่เกิดเหตุ, dtype: float64

# %%
dataframe1 = merged_table_nm.replace([small['จำนวนครั้งที่เกิดเหตุ']], 'น้อย')
dataframe1
# Out:
#           จังหวัด  โรคสมองเสื่อม  ...  โรคลมชัก  จำนวนครั้งที่เกิดเหตุ
# 0          กระบี่            168  ...      1231                    205
# 1   กรุงเทพมหานคร           3002  ...      5646                   1844
# 2       กาญจนบุรี            249  ...      1881                    285
# 3       กาฬสินธุ์            323  ...      2143                    130
# 4       กำแพงเพชร            146  ...      1779                    188
# ..            ...            ...  ...       ...                    ...
# 72     อำนาจเจริญ             99  ...       957                   น้อย
# 73       อุดรธานี            614  ...      3626                    206
# 74      อุตรดิตถ์             86  ...       693                    289
# 75      อุทัยธานี            195  ...       903                    114
# 76    อุบลราชธานี            698  ...      5920                    186
#
# [76 rows x 20 columns]

# %%
dataframe2 = merged_table_nm.replace([middle['จำนวนครั้งที่เกิดเหตุ']], 'ปานกลาง')
dataframe2
# Out:
#           จังหวัด  โรคสมองเสื่อม  ...  โรคลมชัก  จำนวนครั้งที่เกิดเหตุ
# 0          กระบี่            168  ...      1231                    205
# 1   กรุงเทพมหานคร           3002  ...      5646                   1844
# 2       กาญจนบุรี            249  ...      1881                    285
# 3       กาฬสินธุ์            323  ...      2143                ปานกลาง
# 4       กำแพงเพชร            146  ...      1779                ปานกลาง
# ..            ...            ...  ...       ...                    ...
# 72     อำนาจเจริญ             99  ...       957                     51
# 73       อุดรธานี            614  ...      3626                    206
# 74      อุตรดิตถ์             86  ...       693                    289
# 75      อุทัยธานี            195  ...       903                ปานกลาง
# 76    อุบลราชธานี            698  ...      5920                ปานกลาง
#
# [76 rows x 20 columns]

# %%
dataframe3 = merged_table_nm.replace([big['จำนวนครั้งที่เกิดเหตุ']], 'มาก')
dataframe3
# Out:
#           จังหวัด  โรคสมองเสื่อม  ...  โรคลมชัก  จำนวนครั้งที่เกิดเหตุ
# 0          กระบี่            168  ...      1231                    มาก
# 1   กรุงเทพมหานคร           3002  ...      5646                    มาก
# 2       กาญจนบุรี            249  ...      1881                    มาก
# 3       กาฬสินธุ์            323  ...      2143                    130
# 4       กำแพงเพชร            146  ...      1779                    188
# ..            ...            ...  ...       ...                    ...
# 72     อำนาจเจริญ             99  ...       957                     51
# 73       อุดรธานี            614  ...      3626                    มาก
# 74      อุตรดิตถ์             86  ...       693                    มาก
# 75      อุทัยธานี            195  ...       903                    114
# 76    อุบลราชธานี            698  ...      5920                    186
#
# [76 rows x 20 columns]

# %%
dataframe4 = dataframe1.replace([middle['จำนวนครั้งที่เกิดเหตุ']], 'ปานกลาง')
dataframe4
# Out:
#           จังหวัด  โรคสมองเสื่อม  ...  โรคลมชัก  จำนวนครั้งที่เกิดเหตุ
# 0          กระบี่            168  ...      1231                    205
# 1   กรุงเทพมหานคร           3002  ...      5646                   1844
# 2       กาญจนบุรี            249  ...      1881                    285
# 3       กาฬสินธุ์            323  ...      2143                ปานกลาง
# 4       กำแพงเพชร            146  ...      1779                ปานกลาง
# ..            ...            ...  ...       ...                    ...
# 72     อำนาจเจริญ             99  ...       957                   น้อย
# 73       อุดรธานี            614  ...      3626                    206
# 74      อุตรดิตถ์             86  ...       693                    289
# 75      อุทัยธานี            195  ...       903                ปานกลาง
# 76    อุบลราชธานี            698  ...      5920                ปานกลาง
#
# [76 rows x 20 columns]

# %%
dataframe5 = dataframe4.replace([big['จำนวนครั้งที่เกิดเหตุ']], 'มาก')
dataframe5
# Out:
#           จังหวัด  โรคสมองเสื่อม  ...  โรคลมชัก  จำนวนครั้งที่เกิดเหตุ
# 0          กระบี่            168  ...      1231                    มาก
# 1   กรุงเทพมหานคร           3002  ...      5646                    มาก
# 2       กาญจนบุรี            249  ...      1881                    มาก
# 3       กาฬสินธุ์            323  ...      2143                ปานกลาง
# 4       กำแพงเพชร            146  ...      1779                ปานกลาง
# ..            ...            ...  ...       ...                    ...
# 72     อำนาจเจริญ             99  ...       957                   น้อย
# 73       อุดรธานี            614  ...      3626                    มาก
# 74      อุตรดิตถ์             86  ...       693                    มาก
# 75      อุทัยธานี            195  ...       903                ปานกลาง
# 76    อุบลราชธานี            698  ...      5920                ปานกลาง
#
# [76 rows x 20 columns]

# %%
dataframe5.rename(columns={'จำนวนครั้งที่เกิดเหตุ':'ระดับการเกิดอุบัติเหตุ'}, inplace= True)
dataframe5
# Out:
#           จังหวัด  โรคสมองเสื่อม  ...  โรคลมชัก  ระดับการเกิดอุบัติเหตุ
# 0          กระบี่            168  ...      1231                     มาก
# 1   กรุงเทพมหานคร           3002  ...      5646                     มาก
# 2       กาญจนบุรี            249  ...      1881                     มาก
# 3       กาฬสินธุ์            323  ...      2143                 ปานกลาง
# 4       กำแพงเพชร            146  ...      1779                 ปานกลาง
# ..            ...            ...  ...       ...                     ...
# 72     อำนาจเจริญ             99  ...       957                    น้อย
# 73       อุดรธานี            614  ...      3626                     มาก
# 74      อุตรดิตถ์             86  ...       693                     มาก
# 75      อุทัยธานี            195  ...       903                 ปานกลาง
# 76    อุบลราชธานี            698  ...      5920                 ปานกลาง
#
# [76 rows x 20 columns]

# %%
level_accident = dataframe5[['จังหวัด','ระดับการเกิดอุบัติเหตุ']]

# %%
level_accident
# Out:
#           จังหวัด ระดับการเกิดอุบัติเหตุ
# 0          กระบี่                    มาก
# 1   กรุงเทพมหานคร                    มาก
# 2       กาญจนบุรี                    มาก
# 3       กาฬสินธุ์                ปานกลาง
# 4       กำแพงเพชร                ปานกลาง
# ..            ...                    ...
# 72     อำนาจเจริญ                   น้อย
# 73       อุดรธานี                    มาก
# 74      อุตรดิตถ์                    มาก
# 75      อุทัยธานี                ปานกลาง
# 76    อุบลราชธานี                ปานกลาง
#
# [76 rows x 2 columns]

# %%
newtable = merged_table_nm.merge(level_accident,how='left',left_on='จังหวัด',right_on='จังหวัด')

# %%
newtable
# Out:
#           จังหวัด  โรคสมองเสื่อม  ...  จำนวนครั้งที่เกิดเหตุ  ระดับการเกิดอุบัติเหตุ
# 0          กระบี่            168  ...                  205.0                     มาก
# 1   กรุงเทพมหานคร           3002  ...                 1844.0                     มาก
# 2       กาญจนบุรี            249  ...                  285.0                     มาก
# 3       กาฬสินธุ์            323  ...                  130.0                 ปานกลาง
# 4       กำแพงเพชร            146  ...                  188.0                 ปานกลาง
# ..            ...            ...  ...                    ...                     ...
# 71     อำนาจเจริญ             99  ...                   51.0                    น้อย
# 72       อุดรธานี            614  ...                  206.0                     มาก
# 73      อุตรดิตถ์             86  ...                  289.0                     มาก
# 74      อุทัยธานี            195  ...                  114.0                 ปานกลาง
# ...

# %%
newtable.isnull()
# Out:
#     จังหวัด  โรคสมองเสื่อม  ...  จำนวนครั้งที่เกิดเหตุ  ระดับการเกิดอุบัติเหตุ
# 0     False          False  ...                  False                   False
# 1     False          False  ...                  False                   False
# 2     False          False  ...                  False                   False
# 3     False          False  ...                  False                   False
# 4     False          False  ...                  False                   False
# ..      ...            ...  ...                    ...                     ...
# 71    False          False  ...                  False                   False
# 72    False          False  ...                  False                   False
# 73    False          False  ...                  False                   False
# 74    False          False  ...                  False                   False
# 75    False          False  ...                  False                   False
#
# [76 rows x 21 columns]

# %%
newtable.isnull().any()
# Out:
# จังหวัด                                      False
# โรคสมองเสื่อม                                False
# ติดแอลกอฮอลล์                                False
# ติดยาบ้า (Amphetamine)                       False
# ติดสารเสพติดอื่นๆ                            False
# โรคจิตเภท                                    False
# โรคจิตอื่นๆ                                  False
# โรคอารมณ์สองขั้ว                             False
# โรคซึมเศร้า                                  False
# โรควิตกกังวล                                 False
# ความบกพร่องทางสติปัญญา                       False
# ความบกพร่องทางการเรียนรู้                    False
# โรคออทิสติก                                  False
# โรคสมาธิสั้น                                 False
# พยามยามฆ่าตัวตาย (การตั้งใจทำร้ายตนเอง)      False
# ผู้ป่วยติดเกมส์ในผู้ใหญ่ (15 ปีขึ้นไป)       False
# ผู้ป่วยติดเกมส์ในเด็ก (อายุต่ำกว่า 15 ปี)    False
# โรคทางจิตเวชอื่นๆ                            False
# ...

# %%
newtable.isnull().any().any()
# Out:
# False

# %% [markdown]
# # Remove Outlier (boxplot)

# %%
from matplotlib import pyplot as plt

# %%
plt.boxplot(newtable['จำนวนครั้งที่เกิดเหตุ'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f914176dfd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f9140a4d828>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f9140aae128>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f9140a4d780>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f9140a4de10>,
#   <matplotlib.lines.Line2D at 0x7f9140a4d438>]}

# %%
plt.boxplot(newtable['จำนวนครั้งที่เกิดเหตุ'],vert=False)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f914250ad68>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f9142857588>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f9140fb8c18>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f914243d2e8>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f9142857208>,
#   <matplotlib.lines.Line2D at 0x7f91428570f0>]}

# %%
ret = plt.boxplot(newtable['จำนวนครั้งที่เกิดเหตุ'],vert=False)

# %%
ret['whiskers']

# %%
print(ret['whiskers'][0].get_xdata()) #เราปริ้นออกมาดูเพื่อหาขอบเขตมากสุดและน้อยสุดของ whiskers
print(ret['whiskers'][1].get_xdata())
# Out:
# [118.25  35.  ]
# [283.5 461. ]

# %%
no_outlier_no_missing = newtable[(newtable['จำนวนครั้งที่เกิดเหตุ']>=ret['whiskers'][0].get_xdata()[1])]
no_outlier_no_missing = no_outlier_no_missing[(no_outlier_no_missing['จำนวนครั้งที่เกิดเหตุ']<=ret['whiskers'][1].get_xdata()[1])]

# %%
no_outlier_no_missing
# Out:
#         จังหวัด  โรคสมองเสื่อม  ...  จำนวนครั้งที่เกิดเหตุ  ระดับการเกิดอุบัติเหตุ
# 0        กระบี่            168  ...                  205.0                     มาก
# 2     กาญจนบุรี            249  ...                  285.0                     มาก
# 3     กาฬสินธุ์            323  ...                  130.0                 ปานกลาง
# 4     กำแพงเพชร            146  ...                  188.0                 ปานกลาง
# 5       ขอนแก่น           1170  ...                  340.0                     มาก
# ..          ...            ...  ...                    ...                     ...
# 71   อำนาจเจริญ             99  ...                   51.0                    น้อย
# 72     อุดรธานี            614  ...                  206.0                     มาก
# 73    อุตรดิตถ์             86  ...                  289.0                     มาก
# 74    อุทัยธานี            195  ...                  114.0                 ปานกลาง
# ...

# %%
plt.boxplot(no_outlier_no_missing['จำนวนครั้งที่เกิดเหตุ'],vert=False)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f914108afd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f9141099b00>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f91410a9908>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f91410a94a8>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f9141099358>,
#   <matplotlib.lines.Line2D at 0x7f9141099710>]}

# %%
#num_accident_no_nm = no_outlier_no_missing[['จังหวัด','จำนวนครั้งที่เกิดเหตุ']]

# %%
#num_accident_no_nm

# %%
#small = num_accident_no_nm[num_accident_no_nm['จำนวนครั้งที่เกิดเหตุ']<=100]
#small

# %%
#small.shape

# %%
#m = num_accident_no_nm[num_accident_no_nm['จำนวนครั้งที่เกิดเหตุ']>100]
#m

# %%
#middle = m[m['จำนวนครั้งที่เกิดเหตุ']<=200]
#middle

# %%
#middle.shape

# %%
#big = num_accident_no_nm[num_accident_no_nm['จำนวนครั้งที่เกิดเหตุ']>=200]
#big

# %%
#big.shape

# %%
#small['จำนวนครั้งที่เกิดเหตุ']

# %%
#middle['จำนวนครั้งที่เกิดเหตุ']

# %%
#big['จำนวนครั้งที่เกิดเหตุ']

# %%
#dataframe1 = no_outlier_no_missing.replace([small['จำนวนครั้งที่เกิดเหตุ']], 'น้อย')
#dataframe1

# %%
#dataframe2 = no_outlier_no_missing.replace([middle['จำนวนครั้งที่เกิดเหตุ']], 'ปานกลาง')
#dataframe2

# %%
#dataframe3 = no_outlier_no_missing.replace([big['จำนวนครั้งที่เกิดเหตุ']], 'มาก')
#dataframe3

# %%
#dataframe4 = dataframe1.replace([middle['จำนวนครั้งที่เกิดเหตุ']], 'ปานกลาง')
#dataframe4

# %%
#dataframe5 = dataframe4.replace([big['จำนวนครั้งที่เกิดเหตุ']], 'มาก')
#dataframe5

# %%
#dataframe5.rename(columns={'จำนวนครั้งที่เกิดเหตุ':'ระดับการเกิดอุบัติเหตุ'}, inplace= True)
#dataframe5

# %%
#level_accident = dataframe5[['จังหวัด','ระดับการเกิดอุบัติเหตุ']]

# %%
#level_accident

# %%
#newtable_no_outlier_no_missing = no_outlier_no_missing.merge(level_accident,how='left',left_on='จังหวัด',right_on='จังหวัด')

# %%
#newtable_no_outlier_no_missing

# %%
x = [no_outlier_no_missing['จำนวนครั้งที่เกิดเหตุ']]

# %%
plt.hist(x)
# Out:
# (array([ 6., 14.,  6., 14.,  9., 10.,  3.,  4.,  4.,  1.]),
#  array([ 35. ,  77.6, 120.2, 162.8, 205.4, 248. , 290.6, 333.2, 375.8,
#         418.4, 461. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # Classification

# %%
x = no_outlier_no_missing[['โรคสมองเสื่อม','ติดแอลกอฮอลล์','โรคลมชัก']]
x.shape
# Out:
# (71, 3)

# %%
y = no_outlier_no_missing[['ระดับการเกิดอุบัติเหตุ']]
y
# Out:
#    ระดับการเกิดอุบัติเหตุ
# 0                     มาก
# 2                     มาก
# 3                 ปานกลาง
# 4                 ปานกลาง
# 5                     มาก
# ..                    ...
# 71                   น้อย
# 72                    มาก
# 73                    มาก
# 74                ปานกลาง
# 75                ปานกลาง
#
# [71 rows x 1 columns]

# %%
x_train = x.iloc[:-2,:]
print(x_train.shape)
# Out:
# (69, 3)

# %%
x_test = x.iloc[-2:,:]
x_test
# Out:
#     โรคสมองเสื่อม  ติดแอลกอฮอลล์  โรคลมชัก
# 74            195           1060       903
# 75            698           7480      5920

# %%
y_train = y.iloc[:-2]
y_train.shape
# Out:
# (69, 1)

# %%
y_test = y[-2:]
y_test
# Out:
#    ระดับการเกิดอุบัติเหตุ
# 74                ปานกลาง
# 75                ปานกลาง

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
myKNN = KNeighborsClassifier(n_neighbors=3)

# %%
myKNN.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   """Entry point for launching an IPython kernel.
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
myKNN.predict(x_test)
# Out:
# array(['น้อย', 'น้อย'], dtype=object)

# %%
myKNN = KNeighborsClassifier(n_neighbors=50)

# %%
myKNN.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   """Entry point for launching an IPython kernel.
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=50, p=2,
#                      weights='uniform')

# %%
myKNN.predict(x_test)
# Out:
# array(['ปานกลาง', 'มาก'], dtype=object)

# %%
myKNN = KNeighborsClassifier(n_neighbors=60,weights='distance')

# %%
myKNN.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   """Entry point for launching an IPython kernel.
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=60, p=2,
#                      weights='distance')

# %%
myKNN.predict(x_test)
# Out:
# array(['มาก', 'มาก'], dtype=object)

# %%
myKNN = KNeighborsClassifier(n_neighbors=5)

# %%
myKNN.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   """Entry point for launching an IPython kernel.
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
myKNN.predict(x_test)
# Out:
# array(['น้อย', 'มาก'], dtype=object)

# %%
myKNN.predict_proba(x_test)
# Out:
# array([[0.6, 0.2, 0.2],
#        [0.2, 0.2, 0.6]])

# %% [markdown]
# # Selecting the best model

# %%
from sklearn.model_selection import train_test_split

# %%
# 1.แบ่งข้อมูลเป็น train กับ test แล้วเก็บ test เอาไว้

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
print(f'{x_train.shape} {x_test.shape}')
# Out:
# (56, 3) (15, 3)

# %%
# 2.ทำ k-fold cross validation เพื่อเลือก model ที่ดีที่สุด

# %%
from sklearn.model_selection import cross_val_score

# %%
# 1.Import
from sklearn.neighbors import KNeighborsClassifier
# 2.Define model
KNN_k3_wU = KNeighborsClassifier(n_neighbors=3)
# 3.Cross validation
cross_val_score(KNN_k3_wU, x_train, y_train, cv=5).mean()
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
# 1. Define model
KNN_k3_wD =KNeighborsClassifier(n_neighbors=3,weights='distance')
# 2. Cros validation
cross_val_score(KNN_k3_wD, x_train, y_train, cv=5).mean()
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
# 1. Define model
KNN_k3_wE =KNeighborsClassifier(n_neighbors=4)
# 2. Cros validation
cross_val_score(KNN_k3_wE, x_train, y_train, cv=5).mean()
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
# 1. Define model
KNN_k3_wF =KNeighborsClassifier(n_neighbors=4,weights='distance')
# 2. Cros validation
cross_val_score(KNN_k3_wF, x_train, y_train, cv=5).mean()
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
# 1. Define model
KNN_k3_wG =KNeighborsClassifier(n_neighbors=5)
# 2. Cros validation
cross_val_score(KNN_k3_wG, x_train, y_train, cv=5).mean()
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %% [markdown]
# # Train model ที่ดีที่สุดด้วย training set แล้ววัดผลด้วย test set

# %%
#Define
KNN_k3_wG =KNeighborsClassifier(n_neighbors=5)
#train
KNN_k3_wG.fit(x_train,y_train)
#Test_Evaluation
KNN_k3_wG.score(x_test,y_test)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   after removing the cwd from sys.path.
# 0.5333333333333333
